# %%
import json

# %%
data=[{'name': 'Alice', 'rating': '5 ', 'feedback': 'Great product!!', 'age': '25'},
 {'name': 'Bob',
  'rating': 'four',
  'feedback': 'ok but late Delivery',
  'age': '30'},
 {'name': ' Charlie', 'rating': 'two', 'feedback': 'BAD EXPERIENCE '},
 {'name': 'Diana', 'feedback': 'Loved it!', 'rating': '5', 'age': '28'},
 {'name': 'Eve',
  'rating': '3.5',
  'feedback': 'Average - could be better',
  'age': '20'},
 {'name': 'Alice',
  'rating': '5',
  'feedback': 'Great product again!',
  'age': '25'}]
print(data)
# Out:
# [{'name': 'Alice', 'rating': '5 ', 'feedback': 'Great product!!', 'age': '25'}, {'name': 'Bob', 'rating': 'four', 'feedback': 'ok but late Delivery', 'age': '30'}, {'name': ' Charlie', 'rating': 'two', 'feedback': 'BAD EXPERIENCE '}, {'name': 'Diana', 'feedback': 'Loved it!', 'rating': '5', 'age': '28'}, {'name': 'Eve', 'rating': '3.5', 'feedback': 'Average - could be better', 'age': '20'}, {'name': 'Alice', 'rating': '5', 'feedback': 'Great product again!', 'age': '25'}]

# %%
i=0
j=0
n=len(data)
for item in data:
    i=i+float(item.get("rating"))
    x=float(item.get("rating"))
    print(float(item.get("rating")))
    if x<3:
        j=j+1
        print("people who gave less rating are:",item.get("name"))
print(j/n*100)
print(i/n)
# Out:
# 5.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 5
#       3 n=len(data)
#       4 for item in data:
# ----> 5     i=i+float(item.get("rating"))
#       6     x=float(item.get("rating"))
#       7     print(float(item.get("rating")))
#
# ValueError: could not convert string to float: 'four'

# %%
def clean_data(data):
    raw_rating=0
    text_to_num={"one":1,"two":2,"three":3,"four":4,"five":5}
    cleaned_data=[]
    unique_names=set()
    
    for item in data:
       if isinstance(item["rating"],str):
           raw_rating=str(item["rating"].strip().lower())
       if raw_rating in text_to_num:
                raw_rating=text_to_num[raw_rating]
                item["rating"]=raw_rating
        
       raw_age=item.get("age")
       if raw_age==None:
                item["age"]=None
       if item["name"].strip() in unique_names:
           continue
      
        item["name"]=item["name"].strip()
        unique_names.add(item["name"].strip())
        cleaned_data.append(item)item["name"]
    return cleaned_data
# Out:
#   File <string>:20
#     item["name"]=item["name"].strip()
#                                      ^
# IndentationError: unindent does not match any outer indentation level

# %%
data2=clean_data(data)
for i in data:
    nam=i["name"].strip
    print(nam)
# Out:
# <built-in method strip of str object at 0x10b8cdef0>
# <built-in method strip of str object at 0x10b8f95b0>
# <built-in method strip of str object at 0x10b8fabb0>
# <built-in method strip of str object at 0x10b8f8cb0>
# <built-in method strip of str object at 0x10b8c2c30>
# <built-in method strip of str object at 0x10b8cdef0>

# %%
def recommendation(data2):
    final=[]
    for i in data2:
        current={}
        current["name"]=i["name"]
        if float(i["rating"])<=4:
            current["brand"]="apple"
        else:
            current["brand"]="samsang"

        final.append(current)
    for j in final:
        print(j)
recommendation(data2)
# Out:
# {'name': 'Alice', 'brand': 'samsang'}
# {'name': 'Bob', 'brand': 'apple'}
# {'name': ' Charlie', 'brand': 'apple'}
# {'name': 'Diana', 'brand': 'samsang'}
# {'name': 'Eve', 'brand': 'apple'}
